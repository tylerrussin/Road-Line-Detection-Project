# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2
import configparser

# %%
# Acessing Credentials
config = configparser.ConfigParser()
config.read('../credentials/credentials.ini')
USERNAME = config['ElephantSql Road Lane Detection Instance']['USERNAME']
PASSWORD = config['ElephantSql Road Lane Detection Instance']['PASSWORD']
DATABASE = config['ElephantSql Road Lane Detection Instance']['DATABASE']

#Connecting to Postgress instance
elephantsql_client = 'postgresql://' + USERNAME + ':' + PASSWORD + '@kashin.db.elephantsql.com/' + DATABASE

# Initiating database connection
db = create_engine(elephantsql_client)
conn = db.connect()

# %%
df = pd.DataFrame({'name': [
                   'scene_1',
                   'scene_2',
                   'scene_3',
                   'scene_4',
                   'scene_5',
                   'scene_6',
                   'scene_7',
                   'scene_8',
                   'scene_9',
                   'scene_10',
                   'scene_11',
                   'scene_12',
                   'scene_13',
                   'scene_14',
                   'scene_15',
                   'scene_16',
                   'scene_17',
                   'scene_18'
                   ],
                   'weather': [
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear'
                   ],
                   'time_of_day': [
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon',
                   'afternoon'
                   ],
                   'shadows': [
                   'false',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear'
                   ],
                   'road_type': [
                   'highway',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear'
                   ],
                   'traffic': [                   
                   'false',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear'
                   ],
                   'line_condition': [
                   'smooth',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear'
                   ],
                   'lane_count': [
                   '1',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear'
                   ],
                   'pavement': [
                   'smooth',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear'
                   ],
                   'detection_preformence': [
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear',
                   'clear'
                   ]
                   })

# %%
df.to_sql('road_data_table', con=conn, if_exists='replace', index=False)
conn.close()
